# %%
# %load_ext autoreload
# %autoreload 2
import tetra.game
from tetra.game import Game
import matplotlib.pyplot as plt

game = Game()

trajectory = []
while not game.game_over:
    state = game.get_state()
    action = 0 # Replace this with model prediction
    result = game.step(action)
    trajectory.append((state, action, result))
    game.render(show = True)

plt.show()
# Out:
# [(3, 0), (4, 0), (5, 0), (5, 1)]
# [(3, 1), (3, 2), (4, 1), (4, 2)]
# [(3, 3), (4, 3), (5, 3), (6, 3)]
# [(3, 5), (4, 5), (4, 4), (5, 4)]
# [(3, 6), (4, 6), (4, 7), (5, 7)]
# [(3, 8), (4, 8), (4, 9), (5, 8)]
# [(3, 11), (3, 10), (4, 10), (5, 10)]
# [(3, 12), (4, 12), (5, 12), (6, 12)]
# [(3, 13), (4, 13), (4, 14), (5, 13)]
# [(3, 15), (4, 15), (5, 15), (5, 16)]
# [(3, 16), (4, 16), (4, 17), (5, 17)]
# [(3, 18), (3, 19), (4, 18), (4, 19)]

# %%
import tetra

# %%
from tetra.game import Game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from tetra.game import Game
#
# ModuleNotFoundError: No module named 'tetra.game'
