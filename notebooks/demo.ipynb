# %%
# %load_ext autoreload
# %autoreload 2

from tetra.game import Game
from tetra.utils import create_animation
import matplotlib.pyplot as plt

game = Game()

trajectory = []
images = []
while not game.game_over:
    state = game.get_state()
    action = 0 # Replace this with model prediction
    result = game.step(action)
    trajectory.append((state, action, result))
    
    rgb_image = game.render(show=False)
    images.append(rgb_image)

create_animation(images)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <video width="300" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
